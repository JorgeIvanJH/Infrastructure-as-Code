# %% [markdown]
# # Read the hepatitis data
#
# This notebook reads the CSV copied into the SPE image and performs a few simple checks.

# %%
from pathlib import Path

import pandas as pd

data_path = Path("../data/hepatitis.csv")
hepatitis = pd.read_csv(data_path)
hepatitis.head()

# %%
print(f"Rows: {hepatitis.shape[0]}")
print(f"Columns: {hepatitis.shape[1]}")
print(hepatitis.columns.tolist())

# %%
# Empty CSV values are shown as missing values.
hepatitis.isna().sum().sort_values(ascending=False)

# %%
hepatitis["Class"].value_counts().sort_index()
